# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul-Gadadhar/Diabetes-Advisor/blob/main/Diabetes_Advisor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AI-Powered Personalized Diabetes Nutrition Advisor using RNN
#
#
# ---

# %%
import torch
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import precision_score, recall_score, f1_score
import google.generativeai as genai
from google.colab import userdata
from IPython.display import Markdown, display

# %% [markdown]
# ###Loading the Datasets

# %%
from google.colab import drive
drive.mount('/content/drive')

diabetes_data = pd.read_csv(r'/content/drive/My Drive/Datasets/diabetes_patient_data.csv')
pred_food_data = pd.read_csv(r'/content/drive/My Drive/Datasets/pred_food.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Preprocessing the Diabetes Data

# %%
label_encoders = {}

diabetes_data.columns = diabetes_data.columns.str.strip()
pred_food_data.columns = pred_food_data.columns.str.strip()

for column in ['Gender', 'Type of Diabetes', 'Current Medications']:
    le = LabelEncoder()
    diabetes_data[column] = le.fit_transform(diabetes_data[column])
    label_encoders[column] = le

for column in ['Suitable for Diabetes', 'Suitable for Blood Pressure']:
    le = LabelEncoder()
    pred_food_data[column] = le.fit_transform(pred_food_data[column])
    label_encoders[column] = le

# %% [markdown]
# ###Combining and Scaling the data

# %%
combined_data = pd.DataFrame({
    'Age': diabetes_data['Age'],
    'Gender': diabetes_data['Gender'],
    'Type of Diabetes': diabetes_data['Type of Diabetes'],
    'Blood Sugar Levels (mg/dL)': diabetes_data['Blood Sugar Levels (mg/dL)'],
    'Glycemic Index': pred_food_data['Glycemic Index'].iloc[:len(diabetes_data)],
    'Calories': pred_food_data['Calories'].iloc[:len(diabetes_data)],
    'Carbohydrates': pred_food_data['Carbohydrates'].iloc[:len(diabetes_data)],
    'Protein': pred_food_data['Protein'].iloc[:len(diabetes_data)],
    'Fat': pred_food_data['Fat'].iloc[:len(diabetes_data)],
    'Sodium Content': pred_food_data['Sodium Content'].iloc[:len(diabetes_data)],
    'Potassium Content': pred_food_data['Potassium Content'].iloc[:len(diabetes_data)],
    'Magnesium Content': pred_food_data['Magnesium Content'].iloc[:len(diabetes_data)],
    'Calcium Content': pred_food_data['Calcium Content'].iloc[:len(diabetes_data)],
    'Fiber Content': pred_food_data['Fiber Content'].iloc[:len(diabetes_data)]
})

scaler = MinMaxScaler()

features_to_use = ['Age', 'Blood Sugar Levels (mg/dL)', 'Glycemic Index', 'Calories',
                   'Carbohydrates', 'Protein', 'Fat', 'Sodium Content',
                   'Potassium Content', 'Magnesium Content', 'Calcium Content',
                   'Fiber Content']

combined_data[features_to_use] = scaler.fit_transform(
    combined_data[features_to_use]
)

# %% [markdown]
# ###Defining X and y variables

# %%
X = combined_data[features_to_use].values

y = np.random.randint(0, len(pred_food_data), size=(len(combined_data),))
y = np.eye(len(pred_food_data))[y]

X = X.reshape((X.shape[0], 1, X.shape[1]))

X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

# %% [markdown]
# ###Defining the RNN Model

# %%
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.rnn(x)
        out = out[:, -1, :]
        out = self.fc(out)
        return out

input_size = X.shape[2]
hidden_size = 50
output_size = len(pred_food_data)

model = RNNModel(input_size, hidden_size, output_size)

# %% [markdown]
# ###Defining loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ###Training the RNN

# %%
epochs = 500
batch_size = 10

for epoch in range(epochs):
    model.train()
    permutation = torch.randperm(X_tensor.size(0))
    epoch_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    all_true_labels = []
    all_predicted_labels = []

    for i in range(0, X_tensor.size(0), batch_size):
        indices = permutation[i:i + batch_size]
        batch_X, batch_y = X_tensor[indices], y_tensor[indices]

        outputs = model(batch_X)
        loss = criterion(outputs, torch.argmax(batch_y, dim=1))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        true_labels = torch.argmax(batch_y, dim=1)
        all_true_labels.extend(true_labels.cpu().numpy())

        all_predicted_labels.extend(predicted.cpu().numpy())
        total_samples += batch_y.size(0)
        correct_predictions += (predicted == torch.argmax(batch_y, dim=1)).sum().item()

    epoch_loss /= len(X_tensor) / batch_size
    epoch_accuracy = (correct_predictions / total_samples) * 100

    precision = precision_score(all_true_labels, all_predicted_labels, average='weighted', zero_division=0)
    recall = recall_score(all_true_labels, all_predicted_labels, average='weighted', zero_division=0)
    f1 = f1_score(all_true_labels, all_predicted_labels, average='weighted', zero_division=0)

    print(f"Epoch {epoch + 1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%")
print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}")

#Save the model
torch.save(model.state_dict(), 'diabetes_prediction_model.pth')
# Out:
# Epoch 1/500, Loss: 6.7703, Accuracy: 0.00%
# Epoch 2/500, Loss: 6.6848, Accuracy: 0.00%
# Epoch 3/500, Loss: 6.5810, Accuracy: 0.00%
# Epoch 4/500, Loss: 6.4453, Accuracy: 0.99%
# Epoch 5/500, Loss: 6.3000, Accuracy: 0.00%
# Epoch 6/500, Loss: 6.0917, Accuracy: 0.00%
# Epoch 7/500, Loss: 5.8487, Accuracy: 0.99%
# Epoch 8/500, Loss: 5.6518, Accuracy: 0.00%
# Epoch 9/500, Loss: 5.4601, Accuracy: 0.99%
# Epoch 10/500, Loss: 5.3067, Accuracy: 3.96%
# Epoch 11/500, Loss: 5.2128, Accuracy: 2.97%
# Epoch 12/500, Loss: 5.0826, Accuracy: 3.96%
# Epoch 13/500, Loss: 5.0855, Accuracy: 3.96%
# Epoch 14/500, Loss: 5.0445, Accuracy: 4.95%
# Epoch 15/500, Loss: 5.0164, Accuracy: 2.97%
# Epoch 16/500, Loss: 5.0021, Accuracy: 2.97%
# Epoch 17/500, Loss: 4.9765, Accuracy: 2.97%
# Epoch 18/500, Loss: 4.9576, Accuracy: 2.97%
# Epoch 19/500, Loss: 4.9181, Accuracy: 2.97%
# Epoch 20/500, Loss: 4.9487, Accuracy: 3.96%
# Epoch 21/500, Loss: 4.9034, Accuracy: 1.98%
# Epoch 22/500, Loss: 4.9025, Accuracy: 2.97%
# Epoch 23/500, Loss: 4.8976, Accuracy: 1.98%
# Epoch 24/500, Loss: 4.8786, Accuracy: 2.97%
# Epoch 25/500, Loss: 4.8906, Accuracy: 2.97%
# Epoch 26/500, Loss: 4.8958, Accuracy: 3.96%
# Epoch 27/500, Loss: 4.8775, Accuracy: 3.96%
# Epoch 28/500, Loss: 4.8793, Accuracy: 2.97%
# Epoch 29/500, Loss: 4.8209, Accuracy: 3.96%
# Epoch 30/500, Loss: 4.8043, Accuracy: 5.94%
# Epoch 31/500, Loss: 4.8539, Accuracy: 4.95%
# Epoch 32/500, Loss: 4.8596, Accuracy: 5.94%
# Epoch 33/500, Loss: 4.8311, Accuracy: 5.94%
# Epoch 34/500, Loss: 4.8042, Accuracy: 5.94%
# Epoch 35/500, Loss: 4.8305, Accuracy: 6.93%
# Epoch 36/500, Loss: 4.7675, Accuracy: 6.93%
# Epoch 37/500, Loss: 4.7974, Accuracy: 6.93%
# Epoch 38/500, Loss: 4.7904, Accuracy: 5.94%
# Epoch 39/500, Loss: 4.7859, Accuracy: 7.92%
# Epoch 40/500, Loss: 4.7749, Accuracy: 5.94%
# Epoch 41/500, Loss: 4.7456, Accuracy: 6.93%
# Epoch 42/500, Loss: 4.7224, Accuracy: 5.94%
# Epoch 43/500, Loss: 4.7178, Accuracy: 6.93%
# Epoch 44/500, Loss: 4.6365, Accuracy: 6.93%
# Epoch 45/500, Loss: 4.6566, Accuracy: 5.94%
# Epoch 46/500, Loss: 4.5647, Accuracy: 3.96%
# Epoch 47/500, Loss: 4.7023, Accuracy: 4.95%
# Epoch 48/500, Loss: 4.6784, Accuracy: 5.94%
# Epoch 49/500, Loss: 4.6163, Accuracy: 5.94%
# Epoch 50/500, Loss: 4.6367, Accuracy: 6.93%
# Epoch 51/500, Loss: 4.6187, Accuracy: 6.93%
# Epoch 52/500, Loss: 4.6216, Accuracy: 7.92%
# Epoch 53/500, Loss: 4.4850, Accuracy: 5.94%
# Epoch 54/500, Loss: 4.5943, Accuracy: 8.91%
# Epoch 55/500, Loss: 4.5856, Accuracy: 6.93%
# Epoch 56/500, Loss: 4.5546, Accuracy: 6.93%
# Epoch 57/500, Loss: 4.5635, Accuracy: 6.93%
# Epoch 58/500, Loss: 4.5445, Accuracy: 5.94%
# Epoch 59/500, Loss: 4.5007, Accuracy: 4.95%
# Epoch 60/500, Loss: 4.5000, Accuracy: 7.92%
# Epoch 61/500, Loss: 4.4784, Accuracy: 7.92%
# Epoch 62/500, Loss: 4.4745, Accuracy: 9.90%
# Epoch 63/500, Loss: 4.4158, Accuracy: 9.90%
# Epoch 64/500, Loss: 4.4485, Accuracy: 10.89%
# Epoch 65/500, Loss: 4.2810, Accuracy: 10.89%
# Epoch 66/500, Loss: 4.4180, Accuracy: 9.90%
# Epoch 67/500, Loss: 4.4231, Accuracy: 7.92%
# Epoch 68/500, Loss: 4.4084, Accuracy: 7.92%
# Epoch 69/500, Loss: 4.2902, Accuracy: 9.90%
# Epoch 70/500, Loss: 4.3202, Accuracy: 10.89%
# Epoch 71/500, Loss: 4.3167, Accuracy: 10.89%
# Epoch 72/500, Loss: 4.3265, Accuracy: 12.87%
# Epoch 73/500, Loss: 4.2597, Accuracy: 14.85%
# Epoch 74/500, Loss: 4.2455, Accuracy: 13.86%
# Epoch 75/500, Loss: 4.2638, Accuracy: 15.84%
# Epoch 76/500, Loss: 4.2921, Accuracy: 12.87%
# Epoch 77/500, Loss: 4.2268, Accuracy: 12.87%
# Epoch 78/500, Loss: 4.2368, Accuracy: 12.87%
# Epoch 79/500, Loss: 4.1649, Accuracy: 11.88%
# Epoch 80/500, Loss: 4.1251, Accuracy: 12.87%
# Epoch 81/500, Loss: 4.1235, Accuracy: 14.85%
# Epoch 82/500, Loss: 4.1862, Accuracy: 14.85%
# Epoch 83/500, Loss: 4.1426, Accuracy: 13.86%
# Epoch 84/500, Loss: 3.9329, Accuracy: 14.85%
# Epoch 85/500, Loss: 4.0779, Accuracy: 12.87%
# Epoch 86/500, Loss: 4.1137, Accuracy: 12.87%
# Epoch 87/500, Loss: 4.0215, Accuracy: 12.87%
# Epoch 88/500, Loss: 4.0573, Accuracy: 12.87%
# Epoch 89/500, Loss: 4.0375, Accuracy: 12.87%
# Epoch 90/500, Loss: 4.0265, Accuracy: 13.86%
# Epoch 91/500, Loss: 3.9036, Accuracy: 14.85%
# Epoch 92/500, Loss: 4.0037, Accuracy: 16.83%
# Epoch 93/500, Loss: 3.9105, Accuracy: 16.83%
# Epoch 94/500, Loss: 3.8847, Accuracy: 16.83%
# Epoch 95/500, Loss: 3.8180, Accuracy: 16.83%
# Epoch 96/500, Loss: 3.8492, Accuracy: 17.82%
# Epoch 97/500, Loss: 3.8509, Accuracy: 18.81%
# Epoch 98/500, Loss: 3.7292, Accuracy: 18.81%
# Epoch 99/500, Loss: 3.8090, Accuracy: 22.77%
# Epoch 100/500, Loss: 3.8726, Accuracy: 22.77%
# Epoch 101/500, Loss: 3.8322, Accuracy: 24.75%
# Epoch 102/500, Loss: 3.7489, Accuracy: 24.75%
# Epoch 103/500, Loss: 3.7720, Accuracy: 21.78%
# Epoch 104/500, Loss: 3.7940, Accuracy: 22.77%
# Epoch 105/500, Loss: 3.6895, Accuracy: 22.77%
# Epoch 106/500, Loss: 3.5770, Accuracy: 23.76%
# Epoch 107/500, Loss: 3.6529, Accuracy: 24.75%
# Epoch 108/500, Loss: 3.6620, Accuracy: 24.75%
# Epoch 109/500, Loss: 3.6421, Accuracy: 24.75%
# Epoch 110/500, Loss: 3.6578, Accuracy: 25.74%
# Epoch 111/500, Loss: 3.5936, Accuracy: 27.72%
# Epoch 112/500, Loss: 3.6202, Accuracy: 26.73%
# Epoch 113/500, Loss: 3.4696, Accuracy: 25.74%
# Epoch 114/500, Loss: 3.5287, Accuracy: 27.72%
# Epoch 115/500, Loss: 3.5520, Accuracy: 28.71%
# Epoch 116/500, Loss: 3.4752, Accuracy: 29.70%
# Epoch 117/500, Loss: 3.5094, Accuracy: 29.70%
# Epoch 118/500, Loss: 3.5091, Accuracy: 31.68%
# Epoch 119/500, Loss: 3.4053, Accuracy: 33.66%
# Epoch 120/500, Loss: 3.4568, Accuracy: 31.68%
# Epoch 121/500, Loss: 3.3959, Accuracy: 33.66%
# Epoch 122/500, Loss: 3.2459, Accuracy: 32.67%
# Epoch 123/500, Loss: 3.2524, Accuracy: 30.69%
# Epoch 124/500, Loss: 3.4006, Accuracy: 31.68%
# Epoch 125/500, Loss: 3.3041, Accuracy: 28.71%
# Epoch 126/500, Loss: 3.3124, Accuracy: 28.71%
# Epoch 127/500, Loss: 3.3139, Accuracy: 31.68%
# Epoch 128/500, Loss: 3.2304, Accuracy: 35.64%
# Epoch 129/500, Loss: 3.2507, Accuracy: 37.62%
# Epoch 130/500, Loss: 3.1339, Accuracy: 37.62%
# Epoch 131/500, Loss: 3.2625, Accuracy: 40.59%
# Epoch 132/500, Loss: 3.1212, Accuracy: 40.59%
# Epoch 133/500, Loss: 3.2452, Accuracy: 38.61%
# Epoch 134/500, Loss: 3.2198, Accuracy: 38.61%
# Epoch 135/500, Loss: 3.0328, Accuracy: 39.60%
# Epoch 136/500, Loss: 3.1362, Accuracy: 39.60%
# Epoch 137/500, Loss: 3.0620, Accuracy: 38.61%
# Epoch 138/500, Loss: 3.0872, Accuracy: 40.59%
# Epoch 139/500, Loss: 3.0846, Accuracy: 41.58%
# Epoch 140/500, Loss: 3.1403, Accuracy: 41.58%
# Epoch 141/500, Loss: 2.9601, Accuracy: 42.57%
# Epoch 142/500, Loss: 3.0483, Accuracy: 43.56%
# Epoch 143/500, Loss: 3.0342, Accuracy: 43.56%
# Epoch 144/500, Loss: 2.9712, Accuracy: 44.55%
# Epoch 145/500, Loss: 3.0304, Accuracy: 45.54%
# Epoch 146/500, Loss: 2.9187, Accuracy: 47.52%
# Epoch 147/500, Loss: 2.9673, Accuracy: 47.52%
# Epoch 148/500, Loss: 2.8540, Accuracy: 48.51%
# Epoch 149/500, Loss: 2.8814, Accuracy: 48.51%
# Epoch 150/500, Loss: 2.9200, Accuracy: 48.51%
# Epoch 151/500, Loss: 2.8865, Accuracy: 48.51%
# Epoch 152/500, Loss: 2.8634, Accuracy: 50.50%
# Epoch 153/500, Loss: 2.7807, Accuracy: 48.51%
# Epoch 154/500, Loss: 2.7958, Accuracy: 47.52%
# Epoch 155/500, Loss: 2.7836, Accuracy: 49.50%
# Epoch 156/500, Loss: 2.7476, Accuracy: 49.50%
# Epoch 157/500, Loss: 2.7282, Accuracy: 49.50%
# Epoch 158/500, Loss: 2.8242, Accuracy: 49.50%
# Epoch 159/500, Loss: 2.6720, Accuracy: 50.50%
# Epoch 160/500, Loss: 2.8086, Accuracy: 51.49%
# Epoch 161/500, Loss: 2.6941, Accuracy: 51.49%
# Epoch 162/500, Loss: 2.6373, Accuracy: 51.49%
# Epoch 163/500, Loss: 2.7231, Accuracy: 52.48%
# Epoch 164/500, Loss: 2.7065, Accuracy: 55.45%
# Epoch 165/500, Loss: 2.6024, Accuracy: 54.46%
# Epoch 166/500, Loss: 2.4588, Accuracy: 54.46%
# Epoch 167/500, Loss: 2.5582, Accuracy: 52.48%
# Epoch 168/500, Loss: 2.5375, Accuracy: 53.47%
# Epoch 169/500, Loss: 2.6306, Accuracy: 56.44%
# Epoch 170/500, Loss: 2.6691, Accuracy: 57.43%
# Epoch 171/500, Loss: 2.6282, Accuracy: 58.42%
# Epoch 172/500, Loss: 2.4778, Accuracy: 59.41%
# Epoch 173/500, Loss: 2.4378, Accuracy: 59.41%
# Epoch 174/500, Loss: 2.5591, Accuracy: 57.43%
# Epoch 175/500, Loss: 2.5507, Accuracy: 55.45%
# Epoch 176/500, Loss: 2.5516, Accuracy: 58.42%
# Epoch 177/500, Loss: 2.5291, Accuracy: 59.41%
# Epoch 178/500, Loss: 2.4595, Accuracy: 62.38%
# Epoch 179/500, Loss: 2.3244, Accuracy: 61.39%
# Epoch 180/500, Loss: 2.4259, Accuracy: 62.38%
# Epoch 181/500, Loss: 2.4456, Accuracy: 63.37%
# Epoch 182/500, Loss: 2.3109, Accuracy: 62.38%
# Epoch 183/500, Loss: 2.4480, Accuracy: 63.37%
# Epoch 184/500, Loss: 2.3234, Accuracy: 65.35%
# Epoch 185/500, Loss: 2.4087, Accuracy: 66.34%
# Epoch 186/500, Loss: 2.3916, Accuracy: 68.32%
# Epoch 187/500, Loss: 2.3935, Accuracy: 69.31%
# Epoch 188/500, Loss: 2.3454, Accuracy: 68.32%
# Epoch 189/500, Loss: 2.3805, Accuracy: 67.33%
# Epoch 190/500, Loss: 2.2173, Accuracy: 64.36%
# Epoch 191/500, Loss: 2.3313, Accuracy: 66.34%
# Epoch 192/500, Loss: 2.2850, Accuracy: 67.33%
# Epoch 193/500, Loss: 2.2096, Accuracy: 65.35%
# Epoch 194/500, Loss: 2.2501, Accuracy: 65.35%
# Epoch 195/500, Loss: 2.2095, Accuracy: 67.33%
# Epoch 196/500, Loss: 2.2376, Accuracy: 63.37%
# Epoch 197/500, Loss: 2.1514, Accuracy: 64.36%
# Epoch 198/500, Loss: 2.1812, Accuracy: 65.35%
# Epoch 199/500, Loss: 2.1554, Accuracy: 66.34%
# Epoch 200/500, Loss: 2.1319, Accuracy: 67.33%
# Epoch 201/500, Loss: 2.1849, Accuracy: 67.33%
# Epoch 202/500, Loss: 2.1210, Accuracy: 68.32%
# Epoch 203/500, Loss: 2.0290, Accuracy: 66.34%
# Epoch 204/500, Loss: 2.0315, Accuracy: 66.34%
# Epoch 205/500, Loss: 2.0344, Accuracy: 68.32%
# Epoch 206/500, Loss: 2.1422, Accuracy: 68.32%
# Epoch 207/500, Loss: 2.0142, Accuracy: 71.29%
# Epoch 208/500, Loss: 1.9486, Accuracy: 70.30%
# Epoch 209/500, Loss: 1.9458, Accuracy: 71.29%
# Epoch 210/500, Loss: 2.0126, Accuracy: 70.30%
# Epoch 211/500, Loss: 1.9662, Accuracy: 72.28%
# Epoch 212/500, Loss: 2.0089, Accuracy: 72.28%
# Epoch 213/500, Loss: 2.1121, Accuracy: 73.27%
# Epoch 214/500, Loss: 1.9103, Accuracy: 72.28%
# Epoch 215/500, Loss: 1.8874, Accuracy: 74.26%
# Epoch 216/500, Loss: 1.9827, Accuracy: 73.27%
# Epoch 217/500, Loss: 2.0420, Accuracy: 73.27%
# Epoch 218/500, Loss: 1.8580, Accuracy: 71.29%
# Epoch 219/500, Loss: 1.8727, Accuracy: 70.30%
# Epoch 220/500, Loss: 1.8006, Accuracy: 69.31%
# Epoch 221/500, Loss: 1.9495, Accuracy: 68.32%
# Epoch 222/500, Loss: 1.8682, Accuracy: 70.30%
# Epoch 223/500, Loss: 1.8201, Accuracy: 71.29%
# Epoch 224/500, Loss: 1.8960, Accuracy: 74.26%
# Epoch 225/500, Loss: 1.8714, Accuracy: 74.26%
# Epoch 226/500, Loss: 1.7792, Accuracy: 75.25%
# Epoch 227/500, Loss: 1.8013, Accuracy: 72.28%
# Epoch 228/500, Loss: 1.9039, Accuracy: 73.27%
# Epoch 229/500, Loss: 1.7228, Accuracy: 72.28%
# Epoch 230/500, Loss: 1.7969, Accuracy: 72.28%
# Epoch 231/500, Loss: 1.7346, Accuracy: 71.29%
# Epoch 232/500, Loss: 1.7530, Accuracy: 69.31%
# Epoch 233/500, Loss: 1.7015, Accuracy: 69.31%
# Epoch 234/500, Loss: 1.7399, Accuracy: 72.28%
# Epoch 235/500, Loss: 1.7800, Accuracy: 70.30%
# Epoch 236/500, Loss: 1.6911, Accuracy: 70.30%
# Epoch 237/500, Loss: 1.6639, Accuracy: 71.29%
# Epoch 238/500, Loss: 1.8356, Accuracy: 72.28%
# Epoch 239/500, Loss: 1.7549, Accuracy: 71.29%
# Epoch 240/500, Loss: 1.7632, Accuracy: 73.27%
# Epoch 241/500, Loss: 1.5948, Accuracy: 71.29%
# Epoch 242/500, Loss: 1.7790, Accuracy: 69.31%
# Epoch 243/500, Loss: 1.6745, Accuracy: 71.29%
# Epoch 244/500, Loss: 1.6653, Accuracy: 73.27%
# Epoch 245/500, Loss: 1.5812, Accuracy: 74.26%
# Epoch 246/500, Loss: 1.6810, Accuracy: 73.27%
# Epoch 247/500, Loss: 1.6045, Accuracy: 75.25%
# Epoch 248/500, Loss: 1.6911, Accuracy: 74.26%
# Epoch 249/500, Loss: 1.6080, Accuracy: 73.27%
# Epoch 250/500, Loss: 1.6598, Accuracy: 74.26%
# Epoch 251/500, Loss: 1.6856, Accuracy: 76.24%
# Epoch 252/500, Loss: 1.6742, Accuracy: 72.28%
# Epoch 253/500, Loss: 1.6817, Accuracy: 74.26%
# Epoch 254/500, Loss: 1.5895, Accuracy: 74.26%
# Epoch 255/500, Loss: 1.5751, Accuracy: 74.26%
# Epoch 256/500, Loss: 1.5243, Accuracy: 75.25%
# Epoch 257/500, Loss: 1.5984, Accuracy: 75.25%
# Epoch 258/500, Loss: 1.5122, Accuracy: 76.24%
# Epoch 259/500, Loss: 1.6305, Accuracy: 77.23%
# Epoch 260/500, Loss: 1.4904, Accuracy: 76.24%
# Epoch 261/500, Loss: 1.4691, Accuracy: 76.24%
# Epoch 262/500, Loss: 1.5088, Accuracy: 78.22%
# Epoch 263/500, Loss: 1.5473, Accuracy: 78.22%
# Epoch 264/500, Loss: 1.5262, Accuracy: 76.24%
# Epoch 265/500, Loss: 1.5557, Accuracy: 76.24%
# Epoch 266/500, Loss: 1.4842, Accuracy: 76.24%
# Epoch 267/500, Loss: 1.5304, Accuracy: 76.24%
# Epoch 268/500, Loss: 1.4555, Accuracy: 76.24%
# Epoch 269/500, Loss: 1.5026, Accuracy: 76.24%
# Epoch 270/500, Loss: 1.5167, Accuracy: 77.23%
# Epoch 271/500, Loss: 1.5241, Accuracy: 79.21%
# Epoch 272/500, Loss: 1.3677, Accuracy: 82.18%
# Epoch 273/500, Loss: 1.4869, Accuracy: 81.19%
# Epoch 274/500, Loss: 1.4779, Accuracy: 82.18%
# Epoch 275/500, Loss: 1.5596, Accuracy: 83.17%
# Epoch 276/500, Loss: 1.4455, Accuracy: 82.18%
# Epoch 277/500, Loss: 1.4776, Accuracy: 81.19%
# Epoch 278/500, Loss: 1.4021, Accuracy: 81.19%
# Epoch 279/500, Loss: 1.3695, Accuracy: 82.18%
# Epoch 280/500, Loss: 1.3997, Accuracy: 82.18%
# Epoch 281/500, Loss: 1.3355, Accuracy: 83.17%
# Epoch 282/500, Loss: 1.4616, Accuracy: 83.17%
# Epoch 283/500, Loss: 1.3744, Accuracy: 83.17%
# Epoch 284/500, Loss: 1.2951, Accuracy: 84.16%
# Epoch 285/500, Loss: 1.3307, Accuracy: 86.14%
# Epoch 286/500, Loss: 1.3396, Accuracy: 85.15%
# Epoch 287/500, Loss: 1.2984, Accuracy: 85.15%
# Epoch 288/500, Loss: 1.3535, Accuracy: 84.16%
# Epoch 289/500, Loss: 1.3508, Accuracy: 84.16%
# Epoch 290/500, Loss: 1.4317, Accuracy: 81.19%
# Epoch 291/500, Loss: 1.2850, Accuracy: 81.19%
# Epoch 292/500, Loss: 1.4611, Accuracy: 84.16%
# Epoch 293/500, Loss: 1.3249, Accuracy: 84.16%
# Epoch 294/500, Loss: 1.2479, Accuracy: 83.17%
# Epoch 295/500, Loss: 1.3177, Accuracy: 83.17%
# Epoch 296/500, Loss: 1.2288, Accuracy: 81.19%
# Epoch 297/500, Loss: 1.3530, Accuracy: 83.17%
# Epoch 298/500, Loss: 1.2582, Accuracy: 80.20%
# Epoch 299/500, Loss: 1.2354, Accuracy: 83.17%
# Epoch 300/500, Loss: 1.2553, Accuracy: 82.18%
# Epoch 301/500, Loss: 1.2519, Accuracy: 83.17%
# Epoch 302/500, Loss: 1.2367, Accuracy: 83.17%
# Epoch 303/500, Loss: 1.1680, Accuracy: 83.17%
# Epoch 304/500, Loss: 1.2357, Accuracy: 83.17%
# Epoch 305/500, Loss: 1.3571, Accuracy: 84.16%
# Epoch 306/500, Loss: 1.2345, Accuracy: 83.17%
# Epoch 307/500, Loss: 1.2779, Accuracy: 83.17%
# Epoch 308/500, Loss: 1.1584, Accuracy: 83.17%
# Epoch 309/500, Loss: 1.2389, Accuracy: 82.18%
# Epoch 310/500, Loss: 1.1361, Accuracy: 83.17%
# Epoch 311/500, Loss: 1.2205, Accuracy: 85.15%
# Epoch 312/500, Loss: 1.1737, Accuracy: 85.15%
# Epoch 313/500, Loss: 1.2459, Accuracy: 85.15%
# Epoch 314/500, Loss: 1.2169, Accuracy: 86.14%
# Epoch 315/500, Loss: 1.2506, Accuracy: 86.14%
# Epoch 316/500, Loss: 1.1115, Accuracy: 86.14%
# Epoch 317/500, Loss: 1.2569, Accuracy: 86.14%
# Epoch 318/500, Loss: 1.2713, Accuracy: 86.14%
# Epoch 319/500, Loss: 1.2284, Accuracy: 85.15%
# Epoch 320/500, Loss: 1.2031, Accuracy: 86.14%
# Epoch 321/500, Loss: 1.1654, Accuracy: 86.14%
# Epoch 322/500, Loss: 1.0892, Accuracy: 85.15%
# Epoch 323/500, Loss: 1.0951, Accuracy: 84.16%
# Epoch 324/500, Loss: 1.2077, Accuracy: 83.17%
# Epoch 325/500, Loss: 1.1674, Accuracy: 87.13%
# Epoch 326/500, Loss: 1.1367, Accuracy: 88.12%
# Epoch 327/500, Loss: 1.0906, Accuracy: 89.11%
# Epoch 328/500, Loss: 1.0589, Accuracy: 88.12%
# Epoch 329/500, Loss: 1.2136, Accuracy: 88.12%
# Epoch 330/500, Loss: 1.1586, Accuracy: 89.11%
# Epoch 331/500, Loss: 1.1037, Accuracy: 89.11%
# Epoch 332/500, Loss: 1.1453, Accuracy: 89.11%
# Epoch 333/500, Loss: 1.1494, Accuracy: 88.12%
# Epoch 334/500, Loss: 1.0415, Accuracy: 89.11%
# Epoch 335/500, Loss: 1.1381, Accuracy: 88.12%
# Epoch 336/500, Loss: 1.0663, Accuracy: 87.13%
# Epoch 337/500, Loss: 1.1007, Accuracy: 91.09%
# Epoch 338/500, Loss: 1.0741, Accuracy: 91.09%
# Epoch 339/500, Loss: 1.1210, Accuracy: 90.10%
# Epoch 340/500, Loss: 1.0039, Accuracy: 90.10%
# Epoch 341/500, Loss: 0.9929, Accuracy: 91.09%
# Epoch 342/500, Loss: 1.0922, Accuracy: 91.09%
# Epoch 343/500, Loss: 1.0300, Accuracy: 91.09%
# Epoch 344/500, Loss: 1.0117, Accuracy: 91.09%
# Epoch 345/500, Loss: 1.0748, Accuracy: 91.09%
# Epoch 346/500, Loss: 0.9885, Accuracy: 91.09%
# Epoch 347/500, Loss: 0.9797, Accuracy: 91.09%
# Epoch 348/500, Loss: 1.1062, Accuracy: 90.10%
# Epoch 349/500, Loss: 0.9679, Accuracy: 90.10%
# Epoch 350/500, Loss: 1.0169, Accuracy: 90.10%
# Epoch 351/500, Loss: 0.9920, Accuracy: 90.10%
# Epoch 352/500, Loss: 1.0314, Accuracy: 90.10%
# Epoch 353/500, Loss: 1.0050, Accuracy: 90.10%
# Epoch 354/500, Loss: 1.0828, Accuracy: 88.12%
# Epoch 355/500, Loss: 1.0559, Accuracy: 90.10%
# Epoch 356/500, Loss: 1.0241, Accuracy: 89.11%
# Epoch 357/500, Loss: 0.9271, Accuracy: 89.11%
# Epoch 358/500, Loss: 0.9358, Accuracy: 89.11%
# Epoch 359/500, Loss: 0.9473, Accuracy: 89.11%
# Epoch 360/500, Loss: 1.0722, Accuracy: 89.11%
# Epoch 361/500, Loss: 0.9471, Accuracy: 89.11%
# Epoch 362/500, Loss: 0.9558, Accuracy: 88.12%
# Epoch 363/500, Loss: 0.9120, Accuracy: 88.12%
# Epoch 364/500, Loss: 1.0379, Accuracy: 89.11%
# Epoch 365/500, Loss: 0.9121, Accuracy: 89.11%
# Epoch 366/500, Loss: 0.9914, Accuracy: 89.11%
# Epoch 367/500, Loss: 0.9895, Accuracy: 90.10%
# Epoch 368/500, Loss: 0.9786, Accuracy: 89.11%
# Epoch 369/500, Loss: 0.9899, Accuracy: 89.11%
# Epoch 370/500, Loss: 0.9886, Accuracy: 89.11%
# Epoch 371/500, Loss: 0.8738, Accuracy: 88.12%
# Epoch 372/500, Loss: 0.9152, Accuracy: 88.12%
# Epoch 373/500, Loss: 1.0147, Accuracy: 90.10%
# Epoch 374/500, Loss: 0.9018, Accuracy: 90.10%
# Epoch 375/500, Loss: 0.9755, Accuracy: 91.09%
# Epoch 376/500, Loss: 0.9404, Accuracy: 91.09%
# Epoch 377/500, Loss: 0.8692, Accuracy: 92.08%
# Epoch 378/500, Loss: 0.8577, Accuracy: 91.09%
# Epoch 379/500, Loss: 0.9802, Accuracy: 93.07%
# Epoch 380/500, Loss: 0.8435, Accuracy: 93.07%
# Epoch 381/500, Loss: 0.9735, Accuracy: 93.07%
# Epoch 382/500, Loss: 0.9298, Accuracy: 92.08%
# Epoch 383/500, Loss: 0.9259, Accuracy: 92.08%
# Epoch 384/500, Loss: 0.8346, Accuracy: 93.07%
# Epoch 385/500, Loss: 0.8597, Accuracy: 93.07%
# Epoch 386/500, Loss: 0.8253, Accuracy: 94.06%
# Epoch 387/500, Loss: 0.8466, Accuracy: 94.06%
# Epoch 388/500, Loss: 0.8396, Accuracy: 94.06%
# Epoch 389/500, Loss: 0.8544, Accuracy: 95.05%
# Epoch 390/500, Loss: 0.8992, Accuracy: 95.05%
# Epoch 391/500, Loss: 0.8865, Accuracy: 95.05%
# Epoch 392/500, Loss: 0.8101, Accuracy: 94.06%
# Epoch 393/500, Loss: 0.9105, Accuracy: 94.06%
# Epoch 394/500, Loss: 0.8213, Accuracy: 93.07%
# Epoch 395/500, Loss: 0.8473, Accuracy: 93.07%
# Epoch 396/500, Loss: 0.9666, Accuracy: 94.06%
# Epoch 397/500, Loss: 0.8862, Accuracy: 94.06%
# Epoch 398/500, Loss: 0.8454, Accuracy: 94.06%
# Epoch 399/500, Loss: 0.8052, Accuracy: 94.06%
# Epoch 400/500, Loss: 0.8519, Accuracy: 92.08%
# Epoch 401/500, Loss: 0.7909, Accuracy: 93.07%
# Epoch 402/500, Loss: 0.7902, Accuracy: 92.08%
# Epoch 403/500, Loss: 0.7765, Accuracy: 93.07%
# Epoch 404/500, Loss: 0.8094, Accuracy: 93.07%
# Epoch 405/500, Loss: 0.8695, Accuracy: 93.07%
# Epoch 406/500, Loss: 0.8351, Accuracy: 93.07%
# Epoch 407/500, Loss: 0.7865, Accuracy: 94.06%
# Epoch 408/500, Loss: 0.8356, Accuracy: 95.05%
# Epoch 409/500, Loss: 0.7591, Accuracy: 95.05%
# Epoch 410/500, Loss: 0.8025, Accuracy: 94.06%
# Epoch 411/500, Loss: 0.8000, Accuracy: 94.06%
# Epoch 412/500, Loss: 0.7820, Accuracy: 93.07%
# Epoch 413/500, Loss: 0.7559, Accuracy: 93.07%
# Epoch 414/500, Loss: 0.8265, Accuracy: 93.07%
# Epoch 415/500, Loss: 0.8031, Accuracy: 93.07%
# Epoch 416/500, Loss: 0.8426, Accuracy: 93.07%
# Epoch 417/500, Loss: 0.7943, Accuracy: 91.09%
# Epoch 418/500, Loss: 0.7543, Accuracy: 90.10%
# Epoch 419/500, Loss: 0.7388, Accuracy: 90.10%
# Epoch 420/500, Loss: 0.7621, Accuracy: 92.08%
# Epoch 421/500, Loss: 0.7419, Accuracy: 91.09%
# Epoch 422/500, Loss: 0.8597, Accuracy: 93.07%
# Epoch 423/500, Loss: 0.7907, Accuracy: 92.08%
# Epoch 424/500, Loss: 0.7164, Accuracy: 92.08%
# Epoch 425/500, Loss: 0.7137, Accuracy: 92.08%
# Epoch 426/500, Loss: 0.7984, Accuracy: 93.07%
# Epoch 427/500, Loss: 0.7251, Accuracy: 92.08%
# Epoch 428/500, Loss: 0.7388, Accuracy: 92.08%
# Epoch 429/500, Loss: 0.8258, Accuracy: 92.08%
# Epoch 430/500, Loss: 0.7053, Accuracy: 93.07%
# Epoch 431/500, Loss: 0.7155, Accuracy: 94.06%
# Epoch 432/500, Loss: 0.8109, Accuracy: 94.06%
# Epoch 433/500, Loss: 0.7622, Accuracy: 94.06%
# Epoch 434/500, Loss: 0.7317, Accuracy: 94.06%
# Epoch 435/500, Loss: 0.6837, Accuracy: 93.07%
# Epoch 436/500, Loss: 0.7941, Accuracy: 94.06%
# Epoch 437/500, Loss: 0.7889, Accuracy: 94.06%
# Epoch 438/500, Loss: 0.7640, Accuracy: 94.06%
# Epoch 439/500, Loss: 0.7013, Accuracy: 94.06%
# Epoch 440/500, Loss: 0.7934, Accuracy: 94.06%
# Epoch 441/500, Loss: 0.6740, Accuracy: 94.06%
# Epoch 442/500, Loss: 0.6653, Accuracy: 95.05%
# Epoch 443/500, Loss: 0.7211, Accuracy: 95.05%
# Epoch 444/500, Loss: 0.6649, Accuracy: 95.05%
# Epoch 445/500, Loss: 0.7727, Accuracy: 94.06%
# Epoch 446/500, Loss: 0.6599, Accuracy: 94.06%
# Epoch 447/500, Loss: 0.6667, Accuracy: 94.06%
# Epoch 448/500, Loss: 0.8465, Accuracy: 95.05%
# Epoch 449/500, Loss: 0.6639, Accuracy: 96.04%
# Epoch 450/500, Loss: 0.6730, Accuracy: 96.04%
# Epoch 451/500, Loss: 0.6749, Accuracy: 96.04%
# Epoch 452/500, Loss: 0.7910, Accuracy: 95.05%
# Epoch 453/500, Loss: 0.7554, Accuracy: 96.04%
# Epoch 454/500, Loss: 0.7947, Accuracy: 97.03%
# Epoch 455/500, Loss: 0.6422, Accuracy: 97.03%
# Epoch 456/500, Loss: 0.6373, Accuracy: 97.03%
# Epoch 457/500, Loss: 0.7984, Accuracy: 97.03%
# Epoch 458/500, Loss: 0.6979, Accuracy: 95.05%
# Epoch 459/500, Loss: 0.6332, Accuracy: 96.04%
# Epoch 460/500, Loss: 0.6439, Accuracy: 96.04%
# Epoch 461/500, Loss: 0.6204, Accuracy: 96.04%
# Epoch 462/500, Loss: 0.6679, Accuracy: 96.04%
# Epoch 463/500, Loss: 0.7181, Accuracy: 96.04%
# Epoch 464/500, Loss: 0.6675, Accuracy: 94.06%
# Epoch 465/500, Loss: 0.6831, Accuracy: 94.06%
# Epoch 466/500, Loss: 0.6950, Accuracy: 93.07%
# Epoch 467/500, Loss: 0.7437, Accuracy: 93.07%
# Epoch 468/500, Loss: 0.7111, Accuracy: 91.09%
# Epoch 469/500, Loss: 0.6339, Accuracy: 92.08%
# Epoch 470/500, Loss: 0.6779, Accuracy: 93.07%
# Epoch 471/500, Loss: 0.6269, Accuracy: 93.07%
# Epoch 472/500, Loss: 0.6147, Accuracy: 93.07%
# Epoch 473/500, Loss: 0.5986, Accuracy: 94.06%
# Epoch 474/500, Loss: 0.6042, Accuracy: 95.05%
# Epoch 475/500, Loss: 0.7007, Accuracy: 95.05%
# Epoch 476/500, Loss: 0.5914, Accuracy: 95.05%
# Epoch 477/500, Loss: 0.6706, Accuracy: 95.05%
# Epoch 478/500, Loss: 0.5895, Accuracy: 95.05%
# Epoch 479/500, Loss: 0.5949, Accuracy: 95.05%
# Epoch 480/500, Loss: 0.6645, Accuracy: 95.05%
# Epoch 481/500, Loss: 0.5800, Accuracy: 95.05%
# Epoch 482/500, Loss: 0.7340, Accuracy: 95.05%
# Epoch 483/500, Loss: 0.5950, Accuracy: 94.06%
# Epoch 484/500, Loss: 0.6465, Accuracy: 96.04%
# Epoch 485/500, Loss: 0.5823, Accuracy: 96.04%
# Epoch 486/500, Loss: 0.5668, Accuracy: 96.04%
# Epoch 487/500, Loss: 0.6964, Accuracy: 96.04%
# Epoch 488/500, Loss: 0.5834, Accuracy: 97.03%
# Epoch 489/500, Loss: 0.6096, Accuracy: 96.04%
# Epoch 490/500, Loss: 0.5669, Accuracy: 96.04%
# Epoch 491/500, Loss: 0.6179, Accuracy: 96.04%
# Epoch 492/500, Loss: 0.5684, Accuracy: 96.04%
# Epoch 493/500, Loss: 0.6555, Accuracy: 95.05%
# Epoch 494/500, Loss: 0.5633, Accuracy: 95.05%
# Epoch 495/500, Loss: 0.5689, Accuracy: 95.05%
# Epoch 496/500, Loss: 0.5464, Accuracy: 95.05%
# Epoch 497/500, Loss: 0.6101, Accuracy: 95.05%
# Epoch 498/500, Loss: 0.5501, Accuracy: 95.05%
# Epoch 499/500, Loss: 0.5586, Accuracy: 95.05%
# Epoch 500/500, Loss: 0.6035, Accuracy: 96.04%
# Precision: 0.96, Recall: 0.96, F1-Score: 0.96

# %% [markdown]
# ###Preprocessing User Input

# %%
def preprocess_user_input(age, gender, diabetes_type, blood_sugar_level):
    gender_encoded = label_encoders['Gender'].transform([gender])[0]
    diabetes_type_encoded = label_encoders['Type of Diabetes'].transform([diabetes_type])[0]

    # Create a DataFrame with column names
    new_user_data = pd.DataFrame([{
        'Age': age,
        'Blood Sugar Levels (mg/dL)': blood_sugar_level,
        'Glycemic Index': 0,
        'Calories': 0,
        'Carbohydrates': 0,
        'Protein': 0,
        'Fat': 0,
        'Sodium Content': 0,
        'Potassium Content': 0,
        'Magnesium Content': 0,
        'Calcium Content': 0,
        'Fiber Content': 0
    }])

    # Scale the new user data
    new_user_data_scaled = scaler.transform(new_user_data)
    return torch.tensor(new_user_data_scaled.reshape((1, 1, len(new_user_data_scaled[0]))), dtype=torch.float32)

def recommend_foods(user_input, blood_sugar_level,suggestions):
    model.eval()
    with torch.no_grad():
        predicted_food_index = model(user_input)
        recommended_indices = torch.argsort(predicted_food_index[0], descending=True)[:suggestions]

    recommended_foods = pred_food_data.iloc[recommended_indices.numpy()]

    # Main Recommendations Table
    print("\nRecommended Foods:")
    print("=" * 90)
    print(f"{'Food Name':<20}{'Glycemic Index':<17}{'Blood Sugar Change':<20}{'Impact':<20}{'Calories':<10}")
    print("=" * 90)
    for index, row in recommended_foods.iterrows():
        gi = row['Glycemic Index']
        expected_blood_sugar_change = blood_sugar_level + (gi / 100 * blood_sugar_level)

        if expected_blood_sugar_change < 140:
            category = 'Low Impact'
        elif 140 <= expected_blood_sugar_change <= 180:
            category = 'Moderate Impact'
        else:
            category = 'High Impact'

        print(f"{row['Food Name']:<20}{gi:<17}{expected_blood_sugar_change:<20}{category:<20}{row['Calories']:<10}")
        print("-" * 90)

    # Detailed Nutritional Table
    print("\nNutritional Details for Recommended Foods:")
    print("=" * 120)
    print(f"{'Food Name':<20}{'Carbs(g)':<12}{'Protein(g)':<12}{'Fat(g)':<10}{'Sodium(mg)':<12}"
          f"{'Potassium(mg)':<15}{'Magnesium(mg)':<15}{'Calcium(mg)':<12}{'Fiber (g)':<10}")
    print("=" * 120)
    for index, row in recommended_foods.iterrows():
        print(f"{row['Food Name']:<20}{row['Carbohydrates']:<12}{row['Protein']:<12}{row['Fat']:<10}"
              f"{row['Sodium Content']:<12}{row['Potassium Content']:<15}{row['Magnesium Content']:<15}"
              f"{row['Calcium Content']:<12}{row['Fiber Content']:<10}")
        print("-" * 120)

    return recommended_foods

# %% [markdown]
# ###Generating AI response

# %%
def explain_with_gemini(recommended_foods):

    recommendations_summary = []
    for _, row in recommended_foods.iterrows():
        recommendations_summary.append({
            'Food Name': row['Food Name'],
            'Glycemic Index': row['Glycemic Index'],
            'Carbs': row['Carbohydrates'],
            'Protein': row['Protein'],
            'Fat': row['Fat'],
            'Sodium': row['Sodium Content'],
            'Potassium': row['Potassium Content'],
            'Magnesium': row['Magnesium Content'],
            'Calcium': row['Calcium Content'],
            'Fiber': row['Fiber Content']
        })

    recommendations_text = "\n".join([
        f"Food Name: {rec['Food Name']}, Glycemic Index: {rec['Glycemic Index']}, Carbs: {rec['Carbs']}g, Protein: {rec['Protein']}g, Fat: {rec['Fat']}g, Sodium: {rec['Sodium']}mg, Potassium: {rec['Potassium']}mg, Magnesium: {rec['Magnesium']}mg, Calcium: {rec['Calcium']}mg, Fiber: {rec['Fiber']}g."
        for rec in recommendations_summary
    ])

    # Generate response with Gemini
    api_key = userdata.get('GOOGLE_API_KEY')
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel("gemini-2.0-flash-exp")
    response = model.generate_content(
        f"Provide a well structured explanation of how the following foods can help with diabetic control based on their nutritional content:\n{recommendations_text}. Make sure its short and concise."
    )

    # Display Gemini's response
    print("\nGemini's Explanation:")
    print("=" * 120)
    display(Markdown(response.text))
    print("-" * 120)

# %% [markdown]
# ###User Input and Displaying results

# %%
age = int(input("What's your Age: "))
gender = input("Enter your Gender (Male/Female): ").strip().capitalize()
diabetes_type = input("Enter your type of Diabetes (Type 1/Type 2): ").strip().capitalize()
suggestions = int(input("How many food suggestions would you like?: "))

while True:
    blood_sugar_level = float(input("Enter your blood sugar level (range 70-180 mg/dL): "))
    if 70 <= blood_sugar_level <= 180:
        break
    else:
        print("Please enter a blood sugar level within the typical range (70-180 mg/dL).")

user_input = preprocess_user_input(age, gender, diabetes_type, blood_sugar_level)
recommended_foods = recommend_foods(user_input, blood_sugar_level,suggestions)
print(f"\nAccuracy Metrics:")
print('-'*50)
print(f"Epochs: {epochs} ; Loss: {epoch_loss:.4f} ; Accuracy: {epoch_accuracy:.2f}%")
print(f"Precision: {(precision*100):.2f}% \nRecall: {(recall*100):.2f}% \nF1-Score: {(f1*100):.2f}%")
print('-'*50)
explain_with_gemini(recommended_foods)
# Out:
# What's your Age: 21
# Enter your Gender (Male/Female): Male
# Enter your type of Diabetes (Type 1/Type 2): Type 1
# How many food suggestions would you like?: 5
# Enter your blood sugar level (range 70-180 mg/dL): 123
#
# Recommended Foods:
# ==========================================================================================
# Food Name           Glycemic Index   Blood Sugar Change  Impact              Calories
# ==========================================================================================
# Masoor Dal          25               153.75              Moderate Impact     352
# ------------------------------------------------------------------------------------------
# Greek Yogurt        11               136.53              Low Impact          59
# ------------------------------------------------------------------------------------------
# Pineapple           59               195.57              High Impact         50
# ------------------------------------------------------------------------------------------
# Asparagus           15               141.45              Moderate Impact     20
# ------------------------------------------------------------------------------------------
# Carrots             39               170.97              Moderate Impact     41
# ------------------------------------------------------------------------------------------
#
# Nutritional Details for Recommended Foods:
# ========================================================================================================================
# Food Name           Carbs(g)    Protein(g)  Fat(g)    Sodium(mg)  Potassium(mg)  Magnesium(mg)  Calcium(mg) Fiber (g)
# ========================================================================================================================
# Masoor Dal          63.0        24.0        1.0       6           1202           36             19          7.0
# ------------------------------------------------------------------------------------------------------------------------
# Greek Yogurt        3.6         10.0        0.0       36          141            12             119         0.0
# ------------------------------------------------------------------------------------------------------------------------
# Pineapple           13.0        0.5         0.1       1           109            12             13          1.4
# ------------------------------------------------------------------------------------------------------------------------
# Asparagus           3.7         2.2         0.2       2           202            14             24          2.1
# ------------------------------------------------------------------------------------------------------------------------
# Carrots             10.0        0.9         0.2       69          320            12             33          2.8
# ------------------------------------------------------------------------------------------------------------------------
#
# Accuracy Metrics:
# --------------------------------------------------
# Epochs: 500 ; Loss: 0.5297 ; Accuracy: 91.07%
# Precision: 91.73%
# Recall: 92.45%
# F1-Score: 93.03%
# --------------------------------------------------
#
# Gemini's Explanation:
# ========================================================================================================================
# Okay, here's a breakdown of how each food can contribute to diabetes management based on their nutritional profiles:
#
# **Understanding the Key Factors for Diabetes Control:**
#
# *   **Glycemic Index (GI):**  Measures how quickly a food raises blood sugar levels. Lower GI is better for stable blood sugar.
# *   **Fiber:** Slows down sugar absorption, improving blood sugar control and promoting satiety.
# *   **Protein:** Helps with satiety, slows down glucose absorption, and aids in muscle health, important for overall metabolic health.
# *   **Carbohydrates:** Need to be managed; focusing on complex carbs and balancing intake is important.
# *   **Potassium:** Important for blood pressure control, often affected by diabetes.
# *   **Magnesium:** Plays a role in insulin sensitivity and blood sugar regulation.
#
# **Food Analysis and Diabetes Benefits:**
#
# 1.  **Masoor Dal (Lentils):**
#     *   **Low GI (25):**  Leads to a slow, gradual rise in blood sugar.
#     *   **High Fiber (7.0g):** Further slows sugar absorption, improves blood sugar control and satiety.
#     *   **High Protein (24.0g):** Contributes to satiety and muscle maintenance.
#     *   **High Potassium (1202mg):** Beneficial for blood pressure management.
#     *   **Good Magnesium (36mg):** Helps with insulin sensitivity.
#     *   **Overall:**  Excellent for managing blood sugar due to its combination of low GI, high fiber, and high protein.
#
# 2.  **Greek Yogurt:**
#     *   **Very Low GI (11):** Minimal impact on blood sugar.
#     *   **Good Protein (10.0g):** Promotes satiety and aids in stable blood sugar levels.
#     *   **Good Calcium (119mg):** Important for overall health and bone density.
#     *   **Overall:** Great for a low-carb, high-protein option with minimal impact on blood glucose.
#
# 3.  **Pineapple:**
#     *   **Moderate GI (59):**  Has a moderate impact on blood sugar. Portion control is crucial.
#     *   **Moderate Carb (13.0g):** Must be eaten in moderation due to sugar content.
#     *   **Moderate Fiber (1.4g):** Limited benefit to slowing sugar absorption.
#     *   **Overall:**  Should be consumed in moderation due to its higher GI. Opt for fresh fruit over processed forms like juice or canned.
#
# 4.  **Asparagus:**
#     *   **Very Low GI (15):**  Minimal impact on blood sugar levels.
#     *   **Good Fiber (2.1g):** Helps with blood sugar control and satiety.
#     *   **Good Protein (2.2g):**  Provides a small boost to satiety.
#      *   **Good Potassium (202mg):** Beneficial for blood pressure management.
#     *   **Overall:** An excellent, low-carb vegetable choice with minimal impact on blood sugar.
#
# 5.  **Carrots:**
#     *   **Low GI (39):**  Leads to a slow rise in blood sugar.
#     *   **Good Fiber (2.8g):** Aids in controlling blood sugar levels and satiety.
#     *   **Good Potassium (320mg):**  Beneficial for blood pressure management.
#     *   **Overall:**  A good, low-GI vegetable option, beneficial as a part of a balanced diabetic diet.
#
# **Key Takeaways for Diabetes Control:**
#
# *   Prioritize foods with **low GI** to minimize blood sugar spikes.
# *   Include **high-fiber** foods to slow down glucose absorption.
# *   Incorporate **high-protein** options for satiety and muscle health.
# *   Be mindful of portion sizes, especially with moderate-GI foods like pineapple.
# *   Include nutrient-rich options containing minerals like potassium and magnesium.
# *   **Balance** all these nutrients within your overall diet.
#
# *Disclaimer: This information is for general knowledge purposes only and does not constitute medical advice. It's important to consult a healthcare professional or registered dietitian for personalized dietary recommendations related to diabetes management.*
# ------------------------------------------------------------------------------------------------------------------------
